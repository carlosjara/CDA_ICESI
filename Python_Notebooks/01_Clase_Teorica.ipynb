# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Vectores 
#vacios
kendall_correlations = []
spearman_correlations = []
#rho
rho = np.arange(-0.95, 1.0, 0.05)

# %%
# Bucle
for rho in rho:
    sigma = np.array([[1, rho], [rho, 1]])
    datos = np.random.multivariate_normal([0, 0], sigma, 99999)
    df = pd.DataFrame(datos, columns=['X', 'Y'])
    kendall_corr = df.corr(method='kendall')['X']['Y']  
    spearman_corr = df.corr(method='spearman')['X']['Y']
    
    kendall_correlations.append(kendall_corr)
    spearman_correlations.append(spearman_corr)

# %%
df
# Out:
#               X         Y
# 0     -1.263301 -1.158107
# 1      0.464971 -0.501860
# 2      0.543442  0.797586
# 3     -0.729916 -0.830495
# 4      0.086480 -0.132190
# ...         ...       ...
# 99994 -1.073492 -0.555139
# 99995  1.468494  1.229504
# 99996  0.005711  0.484074
# 99997 -1.532821 -1.434257
# 99998 -0.156952  0.139786
#
# [99999 rows x 2 columns]

# %%
# Graficos
plt.figure(figsize=(10, 6))
plt.plot(rhos, kendall_correlations, label='Kendall')
plt.plot(rhos, spearman_correlations, label='Spearman')
plt.plot(rhos, rhos, 'r--', label='y = x')
plt.axhline(0, color='black', linewidth=0.5) 
plt.axvline(0, color='black', linewidth=0.5)
plt.xlabel('T')
plt.ylabel('SP')
plt.legend()
plt.show()

# %% [markdown]
# ## Solucion por CHATGPT

# %%
#Import de Librerias
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import kendalltau, spearmanr
sns.set_style('whitegrid')

Rho = np.arange(-0.95, 1.0, 0.05)
kendall_correlations = [] #vector vacio 
spearman_correlations = []#vector vacio

for row in Rho:
    sigma = np.array([[1, row], [row, 1]])
    datos = np.random.multivariate_normal([0, 0], sigma, 100000)
    col_x = datos[:, 0]
    col_y = datos[:, 1]
    kendall_corr, _ = kendalltau(col_x, col_y)
    spearman_corr, _ = spearmanr(col_x, col_y)

    kendall_correlations.append(kendall_corr)
    spearman_correlations.append(spearman_corr)
    
plt.figure(figsize=(10, 6))
plt.plot(rhos, kendall_correlations, label='Kendall')
plt.plot(rhos, spearman_correlations, label='Spearman')
plt.plot(rhos, rhos, 'r--', label='y = x')
plt.axhline(0, color='black', linewidth=0.5) 
plt.axvline(0, color='black', linewidth=0.5) 
plt.legend()
plt.show()
